# %% [markdown]
# # Integrations with the Hugging Face Hub

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
import gradio as gr

title = "GPT-J-6B"
description = "Gradio Demo for GPT-J 6B, a transformer model trained using Ben Wang's Mesh Transformer JAX. 'GPT-J' refers to the class of model, while '6B' represents the number of trainable parameters. To use it, simply add your text, or click one of the examples to load them. Read more at the links below."
article = "<p style='text-align: center'><a href='https://github.com/kingoflolz/mesh-transformer-jax' target='_blank'>GPT-J-6B: A 6 Billion Parameter Autoregressive Language Model</a></p>"
examples = [
    ["The tower is 324 metres (1,063 ft) tall,"],
    ["The Moon's orbit around Earth has"],
    ["The smooth Borealis basin in the Northern Hemisphere covers 40%"],
]
demo = gr.load(
    "huggingface/EleutherAI/gpt-j-6B",
    inputs=gr.Textbox(lines=5, label="Input Text"),
    title=title,
    description=description,
    article=article,
    examples=examples,
)

demo.queue()
demo.launch()
# Out:
# Fetching model from: https://huggingface.co/EleutherAI/gpt-j-6B
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

title = "GPT-J-6B"
description = "Gradio Demo for GPT-J 6B, a transformer model trained using Ben Wang's Mesh Transformer JAX. 'GPT-J' refers to the class of model, while '6B' represents the number of trainable parameters. To use it, simply add your text, or click one of the examples to load them. Read more at the links below."
article = "<p style='text-align: center'><a href='https://github.com/kingoflolz/mesh-transformer-jax' target='_blank'>GPT-J-6B: A 6 Billion Parameter Autoregressive Language Model</a></p>"

examples = [
    ["The tower is 324 metres (1,063 ft) tall,"],
    ["The Moon's orbit around Earth has"],
    ["The smooth Borealis basin in the Northern Hemisphere covers 40%"],
]

demo = gr.load(
    "huggingface/EleutherAI/gpt-j-6B",
    inputs=gr.Textbox(
        lines=5,
        label="Input Text"
    ),
    title=title,
    description=description,
    article=article,
    examples=examples,
)

demo.queue()
demo.launch()
# Out:
# Fetching model from: https://huggingface.co/EleutherAI/gpt-j-6B
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

demo = gr.load(
    "abidlabs/remove-bg",
    src="spaces",
)

demo.launch()
# Out:
# Fetching Space from: https://huggingface.co/spaces/abidlabs/remove-bg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 import gradio as gr
#       2
# ----> 3 demo = gr.load(
#       4     "abidlabs/remove-bg",
#       5     src="spaces",
#       6 )
#
# File ~/File/self_learning/OpenCourse/HuggingFace-Course/.venv/lib/python3.12/site-packages/gradio/external.py:96, in load(name, src, token, accept_token, provider, **kwargs)
#      93     return src(name, token, **kwargs)  # type: ignore
#      95 if not accept_token:
# ---> 96     return load_blocks_from_huggingface(
#      97         name=name,
#      98         src=src,  # type: ignore
#      99         token=token,
#     100         provider=provider,
#     101         **kwargs,  # type: ignore
#     102     )
#     103 elif isinstance(accept_token, gr.LoginButton):
#     104     with gr.Blocks(fill_height=True) as demo:
#
# File ~/File/self_learning/OpenCourse/HuggingFace-Course/.venv/lib/python3.12/site-packages/gradio/external.py:187, in load_blocks_from_huggingface(name, src, token, alias, provider, **kwargs)
#     184     Context.token = token
#     186 if src == "spaces":
# --> 187     blocks = from_spaces(
#     188         name, token=token, alias=alias, provider=provider, **kwargs
#     189     )
#     190 else:
#     191     blocks = from_model(name, token=token, alias=alias, provider=provider, **kwargs)
#
# File ~/File/self_learning/OpenCourse/HuggingFace-Course/.venv/lib/python3.12/site-packages/gradio/external.py:555, in from_spaces(space_name, token, alias, provider, **kwargs)
#     553     config = config_request.json()
#     554 else:
# --> 555     raise ValueError(
#     556         f"Could not load the Space: {space_name} because the config could not be fetched."
#     557     )
#     558 if "allow_flagging" in config:  # Create an Interface for Gradio 2.x Spaces
#     559     return from_spaces_interface(
#     560         space_name, config, alias, token, iframe_url, **kwargs
#     561     )
#
# ValueError: Could not load the Space: abidlabs/remove-bg because the config could not be fetched.

# %%
gr.load(
    "spaces/abidlabs/remove-bg", inputs="webcam", title="Remove your webcam background!"
).launch()
# Out:
# Fetching Space from: https://huggingface.co/spaces/abidlabs/remove-bg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gr.load(
#       2     "spaces/abidlabs/remove-bg", inputs="webcam", title="Remove your webcam background!"
#       3 ).launch()
#
# File ~/File/self_learning/OpenCourse/HuggingFace-Course/.venv/lib/python3.12/site-packages/gradio/external.py:96, in load(name, src, token, accept_token, provider, **kwargs)
#      93     return src(name, token, **kwargs)  # type: ignore
#      95 if not accept_token:
# ---> 96     return load_blocks_from_huggingface(
#      97         name=name,
#      98         src=src,  # type: ignore
#      99         token=token,
#     100         provider=provider,
#     101         **kwargs,  # type: ignore
#     102     )
#     103 elif isinstance(accept_token, gr.LoginButton):
#     104     with gr.Blocks(fill_height=True) as demo:
#
# File ~/File/self_learning/OpenCourse/HuggingFace-Course/.venv/lib/python3.12/site-packages/gradio/external.py:187, in load_blocks_from_huggingface(name, src, token, alias, provider, **kwargs)
#     184     Context.token = token
#     186 if src == "spaces":
# --> 187     blocks = from_spaces(
#     188         name, token=token, alias=alias, provider=provider, **kwargs
#     189     )
#     190 else:
#     191     blocks = from_model(name, token=token, alias=alias, provider=provider, **kwargs)
#
# File ~/File/self_learning/OpenCourse/HuggingFace-Course/.venv/lib/python3.12/site-packages/gradio/external.py:555, in from_spaces(space_name, token, alias, provider, **kwargs)
#     553     config = config_request.json()
#     554 else:
# --> 555     raise ValueError(
#     556         f"Could not load the Space: {space_name} because the config could not be fetched."
#     557     )
#     558 if "allow_flagging" in config:  # Create an Interface for Gradio 2.x Spaces
#     559     return from_spaces_interface(
#     560         space_name, config, alias, token, iframe_url, **kwargs
#     561     )
#
# ValueError: Could not load the Space: abidlabs/remove-bg because the config could not be fetched.
