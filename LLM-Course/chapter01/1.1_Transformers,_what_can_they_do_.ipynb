# %% [markdown]
# # Transformers, what can they do?

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# [{'label': 'POSITIVE', 'score': 0.9598046541213989}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598046541213989},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445956707000732, 0.1119767352938652, 0.04342752695083618]}

# %% [markdown]
# > ✏️ **Try it out!** Play around with your own sequences and labels and see how the model behaves.

# %%
classifier(
    ["I am stuyding Large Language Models recently.",
     "The Dow Jones is down 200 points today.",
     "I want to visit Japan next year."],
    candidate_labels=["education", "finance", "travel"],
)
# Out:
# [{'sequence': 'I am stuyding Large Language Models recently.',
#   'labels': ['travel', 'education', 'finance'],
#   'scores': [0.47979143261909485, 0.2715582251548767, 0.24865034222602844]},
#  {'sequence': 'The Dow Jones is down 200 points today.',
#   'labels': ['finance', 'travel', 'education'],
#   'scores': [0.5079371929168701, 0.40471962094306946, 0.08734314888715744]},
#  {'sequence': 'I want to visit Japan next year.',
#   'labels': ['travel', 'finance', 'education'],
#   'scores': [0.9759544730186462, 0.015091124922037125, 0.008954411372542381]}]

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "In this course, we will teach you how to create a simple video game using Python. You will learn about the different modules and functions available in the Pygame library, as well as how to use them to create a basic game loop, handle user input, and draw graphics on the screen. By the end of the course, you should be able to create a simple video game with basic gameplay mechanics.\n\n**Course Outline**\n\n1. **Introduction to Pygame**\n   - Overview of Pygame and its features\n   - Setting up Pygame on your computer\n   - Creating a basic Pygame program\n\n2. **Game Loop**\n   - Understanding the game loop and its importance in game development\n   - Creating a game loop using Pygame\n   - Handling events in the game loop\n\n3. **Handling User Input**\n   - Understanding how to handle user input in Pygame\n   - Using Pygame's built-in functions to handle keyboard and mouse input\n   - Creating functions to handle user input\n\n4. **Drawing Graphics**\n   - Understanding how to draw graphics in Pygame\n   - Using Pygame's built-in functions to draw shapes and lines\n   - Creating functions to draw graphics\n\n5. **Creating a Simple Game**\n   - Creating a simple game using Pygame\n   - Implementing"}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'In this course, we will teach you how to apply for the position in the National Council for Social Responsibility. The next course will be the first in our history of the NSC.\n\n\n\n\nNSC Policy and Practice\nThe National Council for Social Responsibility is currently recruiting students from all over the world to be part of the NSC. The National Council for Social Responsibility is currently recruiting students from all over the world to be part of the NSC.\nThe National Council for Social Responsibility is currently recruiting students from all over the world to be part of the NSC. The National Council for Social Responsibility is currently recruiting students from all over the world to be part of the NSC. In addition, the National Council for Social Responsibility is currently recruiting students from all over the world to be part of the NSC, and will be available to recruit in a variety of ways.\nNSC Policy and Practice\nNSC Policy and Practice.\nThe NSC Policy and Practice.\nThe NSC Policy and Practice.\nThe NSC Policy and Practice.\nThe NSC Policy and Practice.\nThe NSC Policy and Practice.\nThe NSC Policy and Practice.\nWhat We Will Teach You\nNSC Policy and Practice.\nWhat We Will Teach You\nNSC Policy and Practice.'},
#  {'generated_text': 'In this course, we will teach you how to build your own customized tools. The course is free and will cover any of the basic tasks that you may have to do to build your own custom tools. The course will be available online on the website, and on the website for free.\n\n\n\nThe course was designed to be a test of how to build your own custom tools using the tools you use.\nHere are some of our tips:\nThe tool is fairly basic, but it works very well for your needs.\nCreate a custom app\nUse the built-in app that you want to install. In general, create a set of custom apps that will be built with the built-in tool. For example, the first app you want to install will be the app you want to install.\nCreate a custom custom app for your app.\nMake a custom app for your app.\nCreate a new app for your app.\nAdd a simple app to your app.\nCreate a custom app to your app.\nCreate a custom app to your app.\nCreate a custom app for your app.\nUse the built-in App button to create a custom app for your app.\nCreate a custom app for your app.\nUse the built-in App button to create a'}]

# %% [markdown]
# > ✏️ **Try it out!** Use the `num_return_sequences` and `max_length` arguments to generate two sentences of 15 words each.

# %%
generator = pipeline("text-generation", num_return_sequences=2, max_length=15)
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# [{'generated_text': 'In this course, we will teach you how to create a mobile application.'},
#  {'generated_text': 'In this course, we will teach you how to use Python to build a'}]

# %% [markdown]
# > ✏️ **Try it out!** Use the filters to find a text generation model for another language. Feel free to play with the widget and use it in a pipeline!

# %%
generator = pipeline("text-generation", model="HuggingFaceTB/SmolLM3-3B-Base")
generator("今天的午餐我想吃")
# Out:
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': '今天的午餐我想吃一份鸡蛋，可能是煎蛋还是炒鸡蛋。\n但是我却觉得，我的午餐的选择是多余的。\n我不需要煎蛋和炒鸡蛋。\n我不需要鸡蛋和鸡蛋。\n我不需要鸡蛋和鸡蛋。\n我不喜欢鸡蛋。\n今天的午餐，我想吃一份鸡蛋，可能是煎蛋还是炒鸡蛋。\n但是我却觉得，我的午餐的选择是多余的。\n我不需要煎蛋和炒鸡蛋。\n我不需要鸡蛋和鸡蛋。\n我不需要鸡蛋和鸡蛋。\n我不喜欢鸡蛋。\n今天的午餐，我想吃一份鸡蛋，可能是煎蛋还是炒鸡蛋。\n但是我却觉得，我的午餐的选择是多余的。\n我不需要煎蛋和炒鸡蛋。\n我不需要鸡蛋和鸡蛋。\n我不需要鸡蛋和鸡蛋。\n我不喜欢鸡蛋。\n今天的午餐，我想吃一份鸡蛋，可能是煎蛋还是炒鸡蛋。\n但是我却觉得，我的午餐的选择是多余的。\n我不需要'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/106 [00:00<?, ?it/s]
# RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.weight | UNEXPECTED |  |
# roberta.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.196197509765625,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.040527280420064926,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %% [markdown]
# > ✏️ **Try it out!** Search for the `bert-base-cased` model on the Hub and identify its mask word in the Inference API widget. What does this model predict for the sentence in our `pipeline` example above?

# %%
unmasker = pipeline("fill-mask", model="bert-base-cased")
unmasker("This course will teach you all about [MASK] models.", top_k=2)
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# BertForMaskedLM LOAD REPORT from: bert-base-cased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# bert.pooler.dense.bias      | UNEXPECTED |  |
# cls.seq_relationship.weight | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.25963038206100464,
#   'token': 1648,
#   'token_str': 'role',
#   'sequence': 'This course will teach you all about role models.'},
#  {'score': 0.09427279978990555,
#   'token': 1103,
#   'token_str': 'the',
#   'sequence': 'This course will teach you all about the models.'}]

# %%
from transformers import pipeline

ner = pipeline("ner", aggregation_strategy="simple")
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'PER',
#   'score': np.float32(0.9981694),
#   'word': 'Sylvain',
#   'start': 11,
#   'end': 18},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.9796019),
#   'word': 'Hugging Face',
#   'start': 33,
#   'end': 45},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9932106),
#   'word': 'Brooklyn',
#   'start': 49,
#   'end': 57}]

# %% [markdown]
# > ✏️ **Try it out!** Search the Model Hub for a model able to do part-of-speech tagging (usually abbreviated as POS) in English. What does this model predict for the sentence in the example above?

# %%
ner = pipeline("ner", model="dslim/bert-base-NER", aggregation_strategy="simple")
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dslim/bert-base-NER
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'entity_group': 'PER',
#   'score': np.float32(0.9986273),
#   'word': 'S',
#   'start': 11,
#   'end': 12},
#  {'entity_group': 'PER',
#   'score': np.float32(0.93460387),
#   'word': '##yl',
#   'start': 12,
#   'end': 14},
#  {'entity_group': 'PER',
#   'score': np.float32(0.791561),
#   'word': '##va',
#   'start': 14,
#   'end': 16},
#  {'entity_group': 'PER',
#   'score': np.float32(0.9047081),
#   'word': '##in',
#   'start': 16,
#   'end': 18},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.9670036),
#   'word': 'Hu',
#   'start': 33,
#   'end': 35},
#  {'entity_group': 'ORG',
#   'score': np.float32(0.93690354),
#   'word': '##gging Face',
#   'start': 35,
#   'end': 45},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9971419),
#   'word': 'Brooklyn',
#   'start': 49,
#   'end': 57}]

# %%
# Deprecated in transformers v5!
# from transformers import pipeline

# question_answerer = pipeline("question-answering")
# question_answerer(
#     question="Where do I work?",
#     context="My name is Sylvain and I work at Hugging Face in Brooklyn",
# )

# %%
# Deprecated in transformers v5!
# from transformers import pipeline

# summarizer = pipeline("summarization")
# summarizer(
#     """
#     America has changed dramatically during recent years. Not only has the number of
#     graduates in traditional engineering disciplines such as mechanical, civil,
#     electrical, chemical, and aeronautical engineering declined, but in most of
#     the premier American universities engineering curricula now concentrate on
#     and encourage largely the study of engineering science. As a result, there
#     are declining offerings in engineering subjects dealing with infrastructure,
#     the environment, and related issues, and greater concentration on high
#     technology subjects, largely supporting increasingly complex scientific
#     developments. While the latter is important, it should not be at the expense
#     of more traditional engineering.

#     Rapidly developing economies such as China and India, as well as other
#     industrial countries in Europe and Asia, continue to encourage and advance
#     the teaching of engineering. Both China and India, respectively, graduate
#     six and eight times as many traditional engineers as does the United States.
#     Other industrial countries at minimum maintain their output, while America
#     suffers an increasingly serious decline in the number of engineering graduates
#     and a lack of well-educated engineers.
# """
# )

# %%
# Deprecated in transformers v5!
# from transformers import pipeline

# translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
# translator("Ce cours est produit par Hugging Face.")

# %% [markdown]
# > ✏️ **Try it out!** Search for translation models in other languages and try to translate the previous sentence into a few different languages.
