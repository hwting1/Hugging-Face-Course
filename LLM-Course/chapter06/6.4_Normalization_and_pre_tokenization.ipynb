# %% [markdown]
# # Normalization and pre-tokenization

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
print(type(tokenizer.backend_tokenizer))
# Out:
# <class 'tokenizers.Tokenizer'>

# %%
print(tokenizer.backend_tokenizer.normalizer.normalize_str("Héllò hôw are ü?"))
# Out:
# hello how are u?

# %% [markdown]
# > ✏️ **Try it out!** Load a tokenizer from the `bert-base-cased` checkpoint and pass the same example to it. What are the main differences you can see between the cased and uncased versions of the tokenizer?

# %%
new_tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")
print(new_tokenizer.backend_tokenizer.normalizer.normalize_str("Héllò hôw are ü?"))
# Out:
# Héllò hôw are ü?

# %%
tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str("Hello, how are  you?")
# Out:
# [('Hello', (0, 5)),
#  (',', (5, 6)),
#  ('how', (7, 10)),
#  ('are', (11, 14)),
#  ('you', (16, 19)),
#  ('?', (19, 20))]

# %%
tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str("今天的天氣很好，我們應該去哪裡玩？")
# Out:
# [('今天的天氣很好', (0, 7)), ('，', (7, 8)), ('我們應該去哪裡玩', (8, 16)), ('？', (16, 17))]

# %%
tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str("Hello, how are  you?")
# Out:
# [('Hello', (0, 5)),
#  (',', (5, 6)),
#  ('Ġhow', (6, 10)),
#  ('Ġare', (10, 14)),
#  ('Ġ', (14, 15)),
#  ('Ġyou', (15, 19)),
#  ('?', (19, 20))]

# %%
tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str("今天的天氣很好，我們應該去哪裡玩？")
# Out:
# [('ä»Ĭå¤©çļĦå¤©æ°£å¾Īå¥½', (0, 7)),
#  ('ï¼Į', (7, 8)),
#  ('æĪĳåĢĳæĩīè©²åİ»åĵªè£¡çİ©', (8, 16)),
#  ('ï¼Ł', (16, 17))]

# %%
tokenizer = AutoTokenizer.from_pretrained("t5-small")
tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str("Hello, how are  you?")
# Out:
# [('▁Hello,', (0, 6)),
#  ('▁how', (7, 10)),
#  ('▁are', (11, 14)),
#  ('▁you?', (16, 20))]

# %%
tokenizer.backend_tokenizer.pre_tokenizer.pre_tokenize_str("今天的天氣很好，我們應該去哪裡玩？")
# Out:
# [('▁今天的天氣很好，我們應該去哪裡玩？', (0, 17))]
